# %% [markdown]
# hello

# %%
print("Hello sam, welcome to python")
list_01 = [1,2,3,4,5]
from collections import Counter
print(Counter(list_01))
print("Hello sam, welcome to python")
